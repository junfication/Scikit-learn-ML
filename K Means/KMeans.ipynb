# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.datasets import make_blobs

# %%
data = make_blobs(n_samples=200, n_features=2, centers = 4, cluster_std=1.8, random_state=101)

# %%
plt.scatter(data[0][:,0], data[0][:,1], c=data[1], cmap='rainbow')

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=8)

# %%
kmeans.fit(data[0])
# Out:
# KMeans()

# %%
kmeans.cluster_centers_
# Out:
# array([[-3.58703255,  8.92315079],
#        [-9.67203831, -5.13061964],
#        [ 2.15602144,  7.90143199],
#        [ 0.33250207,  0.6136543 ],
#        [ 5.26590106,  6.34716526],
#        [-9.18960987, -8.53584776],
#        [-5.36911865,  6.48192421],
#        [-0.35541842,  4.09237788]])

# %%
kmeans.labels_
# Out:
# array([0, 4, 7, 2, 4, 1, 2, 3, 2, 7, 0, 7, 2, 2, 0, 3, 4, 3, 1, 0, 1, 3,
#        7, 5, 6, 5, 5, 3, 2, 4, 0, 5, 4, 3, 7, 6, 1, 1, 5, 3, 1, 0, 0, 0,
#        7, 2, 0, 7, 5, 7, 3, 6, 4, 3, 1, 7, 7, 3, 6, 2, 5, 2, 1, 0, 2, 3,
#        1, 4, 2, 1, 2, 7, 1, 7, 1, 4, 2, 3, 0, 7, 7, 1, 4, 1, 3, 3, 3, 6,
#        7, 1, 5, 1, 1, 7, 7, 5, 4, 6, 1, 4, 7, 1, 7, 3, 7, 7, 1, 4, 5, 1,
#        4, 0, 6, 2, 5, 4, 0, 0, 2, 0, 7, 6, 3, 6, 3, 4, 0, 3, 5, 0, 6, 0,
#        3, 5, 1, 6, 4, 6, 2, 3, 5, 4, 1, 2, 0, 2, 7, 5, 0, 6, 0, 0, 3, 4,
#        3, 6, 7, 2, 2, 3, 4, 3, 7, 6, 1, 6, 7, 4, 0, 3, 4, 3, 0, 2, 7, 6,
#        2, 2, 5, 2, 0, 5, 5, 0, 1, 5, 1, 5, 5, 3, 1, 4, 4, 0, 1, 7, 4, 4,
#        1, 3], dtype=int32)

# %%
fig , (ax1, ax2) = plt.subplots(1,2, sharey=True, figsize=(10,6))
ax1.set_title('K Means')
ax1.scatter(data[0][:,0], data[0][0:,1], c=kmeans.labels_, cmap='rainbow')
ax2.set_title('Original')
ax2.scatter(data[0][:,0], data[0][0:,1], c=data[1], cmap='rainbow')
